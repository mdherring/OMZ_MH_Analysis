# %% [markdown]
# # Table of Contents
#
# Notebooks are listed in the order they should be run in.
#
# ***00_functions.py*** : a list of all functions (with notes and comments) used for this project compiled into one python document for easy copying and pasting into jupyter notebooks
#
# ## scripts
# ***01_create_proximeta_associations_table*** : creates a master table of all proximeta data
#
# ***02_create_sag_master_table*** : creates a master table of all sag data
#
# ## preliminary_analysis
#
# ***01_proximeta_summary*** : summarizes the master proximeta virus table
# + Virus type breakdown and plot
# + Strength of host-virus associations
#     + plots: distribution of adjusted_inter_vs_intra_ratio
#     + distribution of adjusted_inter_connective_linkage_density
# + Viral copies per cell
#     + plots: jitter and boxplot
# + number of associated vmags and the total number of vmags
#
# ***02_sag_summary*** : plot of the number of associated vsags and the total number of vsags
# + boxplot
#
# ## gtdb-tk
#
# ***04_MAG_gtdb*** : phylogenomic analysis of all mags (with and without viruses associated to them)
# + Input merged mag gtdb table from 03_create_merged_mag_gtdb_table notebook
# + Create lists of ten most abundant taxonomic groups for each level of classification
# + How many MAGs were classified in total?
# + How many MAGs were classified to at least each classification level?
#     + plots: Count and Percent
# + What are the most common classifications?
#     + plots: count of top 10 most abundant phyla, classes, and orders
# + Plots: stacked barplots of top order abundances
#     + count and percent
#
# <u><b> Notes </b></u> : fix color map code to match between all gtdb analysis notebooks
#
# ***06_proximeta_assoc_gtdbtk*** : phylogenomic analysis of mags associated with viruses
# + Input proximeta associations gtdb table from 05_create_proximeta_assoc_gtdb_table notebook
# + Create lists of ten most abundant taxonomic groups for each level of classification
# + How many associations were classified in total?
# + How many associations were classified to at least each classification level?
#     + plots: Count and Percent
# + What are the most common classifications?
#     + plots: count of top 10 most abundant phyla, classes, and orders
# + Plots: stacked barplots of top order abundances
#     + count and percent
#
# <u><b> Notes </b></u> : fix color map code to match between all gtdb analysis notebooks
#
# ***07_sag_assoc_gtdbtk*** : phylogenomic analysis of sags associated with viruses
# + Input sag associations gtdb file from sag_data folder
# + Create lists of ten most abundant taxonomic groups for each level of classification
# + How many associations were classified in total?
# + How many associations were classified to at least each classification level?
#     + plots: Count and Percent
# + What are the most common classifications?
#     + plots: count of top 10 most abundant phyla, classes, and orders
# + Plots: stacked barplots of top order abundances
#     + count and percent
#
# <u><b> Notes </b></u> : fix color map code to match between all gtdb analysis notebooks
#
# ***09_sag_vs_mag_host_tax*** : compare host phylogeny between associated sags and mags
# +
#
# <u><b> Notes </b></u> : fix color map code to match between all gtdb analysis notebooks
#
#
# ## genome_annotation

# %% [markdown]
# To do:
# + fix color maps
# + figure interpretations
#
#
# 1 large table:
# + sample name
# + sample depth
# + virus type: sag, mag, or contig
# + associated host or not
# + gtdbtk
# + summary columns
