# %% [markdown]
# # 12_dramv_candidate_genome_summaries

# %% [markdown]
# This document includes an example command to run DRAM on host genomes and DRAM-v on both vMAGs and vSAGs, as well as summaries of the ouput of dram of the 10 selected genomes in the 10_interesting_virus_host_pairs jupyter notebook.
#
#
# | virus name     | variable name | type | sample depth |
# |----------------|---------------|------| ------------ |
# | vir_AM-654-B04 | vsag1         | vSAG | 80           |
# | vir_AM-654-E17 | vsag2         | vSAG | 80           |
# | vir_AM-656-P04 | vsag3         | vSAG | 95           |
# | vir_AM-662-D22 | vsag4         | vSAG | 140          |
# | vir_AM-666-P13 | vsag5         | vSAG | 400          |
# | jv119_vMAG_29  | vmag1         | vMAG | 400          |
# | jv119_vMAG_32  | vmag2         | vMAG | 400          |
# | jv121_vMAG_31  | vmag3         | vMAG | 95           |
# | jv154_vMAG_31  | vmag4         | vMAG | 140          |
# | jv154_vMAG_44  | vmag5         | vMAG | 140          |

# %% [markdown]
# ## DRAM command line code examples

# %%
# DRAM- for hosts

DRAM.py annotate \
-i 'input_file_path' \ 
-o output_folder_name

DRAM.py distill \
-i annot_output_folder/annotations.tsv \
-o distill_output_folder_name \
--trna_path annot_output_folder/trnas.tsv \
--rrna_path annot_output_folder/rrnas.tsv

# example using a single host SAG file on my laptop

DRAM.py annotate \
-i '~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/genomes/sag_hosts/AM-656-B04_nvcontigs.fasta' \
-o annotations

DRAM.py distill \
-i annotations/annotations.tsv \
-o distill \
--trna_path annotations/trnas.tsv \
--rrna_path annotations/rrnas.tsv

# %%
# DRAM-v

# First, run contigs trough VirSorter to identify the viral contigs. Then concatenate viral contigs into a single file. 
# Run the concatenated fasta file and the VIRSorter_affi-contigs.tab file through DRAM-v.

DRAM-v.py annotate \
-i input_viral_path \
-v VIRSorter_affi-contigs.tab \
-o output_folder_name

DRAM-v.py distill \
-i annot_output_folder/annotations.tsv \
-o distill

# example using a single vSAG file on my laptop

DRAM-v.py annotate \
-i '~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/genomes/vsags/cv1_AM-656-B04.fasta' \
-v VIRSorter_affi-contigs.tab \
-o distill

# %% [markdown]
# ## Load packages and data

# %%
import pandas as pd
import os
import sys
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import glob
import seaborn as sns
from collections import Counter

pd.set_option('display.max_columns', None)

vsag1 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/cv1_AM-654-B04/annotations.tsv", sep = '\t').fillna('NA')
vsag2 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/cv1_AM-654-E17/annotations.tsv", sep = '\t').fillna('NA')
vsag3 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/cv1_AM-656-P04/annotations.tsv", sep = '\t').fillna('NA')
vsag4 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/cv1_AM-662-D22/annotations.tsv", sep = '\t').fillna('NA')
vsag5 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/cv1_AM-666-P13/annotations.tsv", sep = '\t').fillna('NA')

vmag1 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/jv-119-vMAG_29/annotations.tsv", sep = '\t').fillna('NA')
vmag2 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/jv-119-vMAG_32/annotations.tsv", sep = '\t').fillna('NA')
vmag3 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/jv-121-vMAG_31/annotations.tsv", sep = '\t').fillna('NA')
vmag4 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/jv-154-vMAG_31/annotations.tsv", sep = '\t').fillna('NA')
vmag5 = pd.read_csv("~/Documents/Bigelow/Virus_Project/OMZ_MH_Analysis/Data/dramv_output/jv-154-vMAG_44/annotations.tsv", sep = '\t').fillna('NA')

# %% [markdown]
# ## vSAGs

# %% [markdown]
# ### vSAG1

# %%
# How many genes does DRAM-v recognize?
vsag1_annot = vsag1[vsag1['rank'] != 'E'] # E = no annotation
len(vsag1_annot)
# Out:
# 63

# %%
# subset out AMGs
vsag1_amg = vsag1_annot[vsag1_annot['amg_flags'].str.contains('M')]
len(vsag1_amg)
# Out:
# 14

# %%
vsag1_amg['kegg_hit'].value_counts()
# Out:
# NA                                                                      6
# ferredoxin-nitrite reductase [EC:1.7.7.1]                               1
# 3-methyl-2-oxobutanoate hydroxymethyltransferase [EC:2.1.2.11]          1
# GDP-D-mannose 3', 5'-epimerase [EC:5.1.3.18 5.1.3.-]                    1
# ribonucleoside-diphosphate reductase beta chain [EC:1.17.4.1]           1
# phosphoribosylformylglycinamidine cyclo-ligase [EC:6.3.3.1]             1
# phosphoribosylformylglycinamidine synthase subunit PurS [EC:6.3.5.3]    1
# cobaltochelatase CobS [EC:6.6.1.2]                                      1
# ferredoxin                                                              1
# Name: kegg_hit, dtype: int64

# %%
vsag1_amg['viral_hit'].value_counts()
# Out:
# NA                                                                                                                         1
# YP_004324307.1 nucleotide-sugar epimerase [Synechococcus phage S-SSM7]                                                     1
# YP_004322358.1 cysteine dioxygenase [Synechococcus phage S-SM2]                                                            1
# YP_009810871.1 bifunctional heptose 7-phosphate kinase/heptose 1-phosphate adenyltransferase [Synechococcus phage S-T4]    1
# YP_004061678.1 nucleotide-sugar epimerase [Ostreococcus lucimarinus virus 1]                                               1
# YP_009172525.1 hypothetical protein APZ24_gp034 [Ostreococcus lucimarinus virus 2]                                         1
# YP_004322339.1 nucleotide-sugar epimerase [Synechococcus phage S-SM2]                                                      1
# YP_004322326.1 ribonucleoside diphosphate reductase small subunit [Synechococcus phage S-SM2]                              1
# YP_009791335.1 ribonucleotide reductase large subunit [Synechococcus phage Bellamy]                                        1
# YP_009320653.1 phosphoribosylaminoimidazole synthetase [Synechococcus phage S-CAM4]                                        1
# YP_007674478.1 5-phosphoribosylformylglycinamide amidotransferase [Synechococcus phage S-SKS1]                             1
# YP_214386.1 porphyrin biosynthesis [Prochlorococcus phage P-SSM2]                                                          1
# YP_004324849.1 Galactose-3-O-sulfotransferase [Prochlorococcus phage P-SSM7]                                               1
# YP_007674399.1 ferredoxin [Synechococcus phage S-SKS1]                                                                     1
# Name: viral_hit, dtype: int64

# %%
vsag1_amg['pfam_hits'].value_counts()
# Out:
# Nitrite and sulphite reductase 4Fe-4S domain [PF01077.25]; Nitrite/Sulfite reductase ferredoxin-like half domain [PF03460.20]                                                                                      1
# NAD dependent epimerase/dehydratase family [PF01370.24]; GDP-mannose 4,6 dehydratase [PF16363.8]; RmlD substrate binding domain [PF04321.20]                                                                       1
# Mannose-6-phosphate isomerase [PF01050.21]; Cupin [PF00190.25]; D-lyxose isomerase [PF07385.15]                                                                                                                    1
# Cytidylyltransferase-like [PF01467.29]                                                                                                                                                                             1
# NAD dependent epimerase/dehydratase family [PF01370.24]; GDP-mannose 4,6 dehydratase [PF16363.8]; RmlD substrate binding domain [PF04321.20]; 3-beta hydroxysteroid dehydrogenase/isomerase family [PF01073.22]    1
# Ketopantoate hydroxymethyltransferase [PF02548.18]                                                                                                                                                                 1
# GDP-mannose 4,6 dehydratase [PF16363.8]; NAD dependent epimerase/dehydratase family [PF01370.24]; 3-beta hydroxysteroid dehydrogenase/isomerase family [PF01073.22]; RmlD substrate binding domain [PF04321.20]    1
# Ribonucleotide reductase, small chain [PF00268.24]                                                                                                                                                                 1
# Ribonucleotide reductase, barrel domain [PF02867.18]; Ribonucleotide reductase, all-alpha domain [PF00317.24]; ATP cone domain [PF03477.19]                                                                        1
# AIR synthase related protein, N-terminal domain [PF00586.27]; AIR synthase related protein, C-terminal domain [PF02769.25]                                                                                         1
# Phosphoribosylformylglycinamidine (FGAM) synthase [PF02700.17]                                                                                                                                                     1
# AAA domain (dynein-related subfamily) [PF07728.17]; CbbQ/NirQ/NorQ C-terminal [PF08406.13]                                                                                                                         1
# Sulfotransferase family [PF03567.17]                                                                                                                                                                               1
# 2Fe-2S iron-sulfur cluster binding domain [PF00111.30]                                                                                                                                                             1
# Name: pfam_hits, dtype: int64

# %%
vsag1_amg
# Out:
#                            Unnamed: 0           fasta  \
# 2     SCGC_AM-654-B04_contig1||full_3  cv1_AM-654-B04
# 11   SCGC_AM-654-B04_contig1||full_12  cv1_AM-654-B04
# 12   SCGC_AM-654-B04_contig1||full_13  cv1_AM-654-B04
# 15   SCGC_AM-654-B04_contig1||full_16  cv1_AM-654-B04
# 16   SCGC_AM-654-B04_contig1||full_17  cv1_AM-654-B04
# 17   SCGC_AM-654-B04_contig1||full_18  cv1_AM-654-B04
# 26   SCGC_AM-654-B04_contig1||full_27  cv1_AM-654-B04
# 39   SCGC_AM-654-B04_contig1||full_40  cv1_AM-654-B04
# 40   SCGC_AM-654-B04_contig1||full_41  cv1_AM-654-B04
# 55   SCGC_AM-654-B04_contig1||full_56  cv1_AM-654-B04
# 75   SCGC_AM-654-B04_contig1||full_76  cv1_AM-654-B04
# 83   SCGC_AM-654-B04_contig1||full_84  cv1_AM-654-B04
# 89   SCGC_AM-654-B04_contig1||full_90  cv1_AM-654-B04
# 133  SCGC_AM-654-B04_contig41||full_7  cv1_AM-654-B04
#
#                            scaffold  gene_position  start_position  \
# 2     SCGC_AM-654-B04_contig1||full              3             506
# 11    SCGC_AM-654-B04_contig1||full             12            7487
# 12    SCGC_AM-654-B04_contig1||full             13            8340
# 15    SCGC_AM-654-B04_contig1||full             16            9729
# 16    SCGC_AM-654-B04_contig1||full             17           10136
# 17    SCGC_AM-654-B04_contig1||full             18           10977
# 26    SCGC_AM-654-B04_contig1||full             27           18883
# 39    SCGC_AM-654-B04_contig1||full             40           24677
# 40    SCGC_AM-654-B04_contig1||full             41           25818
# 55    SCGC_AM-654-B04_contig1||full             56           38300
# 75    SCGC_AM-654-B04_contig1||full             76           50107
# 83    SCGC_AM-654-B04_contig1||full             84           53411
# 89    SCGC_AM-654-B04_contig1||full             90           58084
# 133  SCGC_AM-654-B04_contig41||full              7            1607
#
#      end_position  strandedness rank   ko_id  \
# 2            2014            -1    C  K00366
# 11           8338            -1    D      NA
# 12           8714            -1    D      NA
# 15          10145            -1    D      NA
# 16          10996            -1    D      NA
# 17          11849            -1    C  K00606
# 26          19953            -1    C  K10046
# 39          25828            -1    C  K00526
# 40          28154            -1    D      NA
# 55          39274            -1    C  K01933
# 75          50361            -1    C  K23264
# 83          54490            -1    C  K09882
# 89          58680            -1    D      NA
# 133          1903             1    C  K02639
#
#                                               kegg_hit        viral_id  \
# 2            ferredoxin-nitrite reductase [EC:1.7.7.1]              NA
# 11                                                  NA  YP_004324307.1
# 12                                                  NA  YP_004322358.1
# 15                                                  NA  YP_009810871.1
# 16                                                  NA  YP_004061678.1
# 17   3-methyl-2-oxobutanoate hydroxymethyltransfera...  YP_009172525.1
# 26   GDP-D-mannose 3', 5'-epimerase [EC:5.1.3.18 5....  YP_004322339.1
# 39   ribonucleoside-diphosphate reductase beta chai...  YP_004322326.1
# 40                                                  NA  YP_009791335.1
# 55   phosphoribosylformylglycinamidine cyclo-ligase...  YP_009320653.1
# 75   phosphoribosylformylglycinamidine synthase sub...  YP_007674478.1
# 83                  cobaltochelatase CobS [EC:6.6.1.2]     YP_214386.1
# 89                                                  NA  YP_004324849.1
# 133                                         ferredoxin  YP_007674399.1
#
#                                              viral_hit viral_RBH  \
# 2                                                   NA        NA
# 11   YP_004324307.1 nucleotide-sugar epimerase [Syn...      True
# 12   YP_004322358.1 cysteine dioxygenase [Synechoco...     False
# 15   YP_009810871.1 bifunctional heptose 7-phosphat...     False
# 16   YP_004061678.1 nucleotide-sugar epimerase [Ost...     False
# 17   YP_009172525.1 hypothetical protein APZ24_gp03...     False
# 26   YP_004322339.1 nucleotide-sugar epimerase [Syn...      True
# 39   YP_004322326.1 ribonucleoside diphosphate redu...      True
# 40   YP_009791335.1 ribonucleotide reductase large ...      True
# 55   YP_009320653.1 phosphoribosylaminoimidazole sy...      True
# 75   YP_007674478.1 5-phosphoribosylformylglycinami...     False
# 83   YP_214386.1 porphyrin biosynthesis [Prochloroc...      True
# 89   YP_004324849.1 Galactose-3-O-sulfotransferase ...     False
# 133  YP_007674399.1 ferredoxin [Synechococcus phage...     False
#
#     viral_identity viral_bitScore viral_eVal peptidase_id peptidase_family  \
# 2               NA             NA         NA           NA               NA
# 11           0.677          379.0        0.0           NA               NA
# 12           0.817          213.0        0.0           NA               NA
# 15           0.579          149.0        0.0           NA               NA
# 16           0.299          104.0        0.0           NA               NA
# 17           0.587          320.0        0.0           NA               NA
# 26           0.799          591.0        0.0           NA               NA
# 39            0.88          702.0        0.0           NA               NA
# 40           0.841         1351.0        0.0           NA               NA
# 55           0.605          377.0        0.0           NA               NA
# 75            0.76          132.0        0.0           NA               NA
# 83           0.807          593.0        0.0           NA               NA
# 89           0.453          162.0        0.0           NA               NA
# 133          0.779          157.0        0.0           NA               NA
#
#     peptidase_hit peptidase_RBH peptidase_identity peptidase_bitScore  \
# 2              NA            NA                 NA                 NA
# 11             NA            NA                 NA                 NA
# 12             NA            NA                 NA                 NA
# 15             NA            NA                 NA                 NA
# 16             NA            NA                 NA                 NA
# 17             NA            NA                 NA                 NA
# 26             NA            NA                 NA                 NA
# 39             NA            NA                 NA                 NA
# 40             NA            NA                 NA                 NA
# 55             NA            NA                 NA                 NA
# 75             NA            NA                 NA                 NA
# 83             NA            NA                 NA                 NA
# 89             NA            NA                 NA                 NA
# 133            NA            NA                 NA                 NA
#
#     peptidase_eVal                                          pfam_hits  \
# 2               NA  Nitrite and sulphite reductase 4Fe-4S domain [...
# 11              NA  NAD dependent epimerase/dehydratase family [PF...
# 12              NA  Mannose-6-phosphate isomerase [PF01050.21]; Cu...
# 15              NA             Cytidylyltransferase-like [PF01467.29]
# 16              NA  NAD dependent epimerase/dehydratase family [PF...
# 17              NA  Ketopantoate hydroxymethyltransferase [PF02548...
# 26              NA  GDP-mannose 4,6 dehydratase [PF16363.8]; NAD d...
# 39              NA  Ribonucleotide reductase, small chain [PF00268...
# 40              NA  Ribonucleotide reductase, barrel domain [PF028...
# 55              NA  AIR synthase related protein, N-terminal domai...
# 75              NA  Phosphoribosylformylglycinamidine (FGAM) synth...
# 83              NA  AAA domain (dynein-related subfamily) [PF07728...
# 89              NA               Sulfotransferase family [PF03567.17]
# 133             NA  2Fe-2S iron-sulfur cluster binding domain [PF0...
#
#     cazy_ids cazy_hits cazy_subfam_ec cazy_best_hit  vogdb_id  \
# 2         NA        NA             NA            NA        NA
# 11        NA        NA             NA            NA  VOG00055
# 12        NA        NA             NA            NA  VOG01945
# 15        NA        NA             NA            NA        NA
# 16        NA        NA             NA            NA  VOG00055
# 17        NA        NA             NA            NA  VOG19288
# 26        NA        NA             NA            NA  VOG00055
# 39        NA        NA             NA            NA  VOG00527
# 40        NA        NA             NA            NA  VOG00122
# 55        NA        NA             NA            NA  VOG09964
# 75        NA        NA             NA            NA  VOG06129
# 83        NA        NA             NA            NA  VOG02489
# 89        NA        NA             NA            NA  VOG17816
# 133       NA        NA             NA            NA  VOG09977
#
#                                             vogdb_hits vogdb_categories  \
# 2                                                   NA               NA
# 11   sp|Q9SYM5|RHM1_ARATH Trifunctional UDP-glucose...               Xh
# 12   sp|P07874|ALGA_PSEAE Alginate biosynthesis pro...               Xh
# 15                                                  NA               NA
# 16   sp|Q9SYM5|RHM1_ARATH Trifunctional UDP-glucose...               Xh
# 17   sp|A6TMH9|PANB_ALKMQ 3-methyl-2-oxobutanoate h...               Xh
# 26   sp|Q9SYM5|RHM1_ARATH Trifunctional UDP-glucose...               Xh
# 39   sp|P69924|RIR2_ECOLI Ribonucleoside-diphosphat...               Xh
# 40   sp|P00452|RIR1_ECOLI Ribonucleoside-diphosphat...               Xh
# 55   sp|Q3AMJ2|PUR5_SYNSC Phosphoribosylformylglyci...               Xh
# 75   sp|Q55842|PURS_SYNY3 Phosphoribosylformylglyci...               Xh
# 83   sp|P04526|LOADL_BPT4 Sliding-clamp-loader larg...            Xr;Xh
# 89           REFSEQ Galactose-3-O-sulfotransferase; Xu               Xu
# 133  sp|P07839|FER_CHLRE Ferredoxin, chloroplastic; Xh               Xh
#
#      heme_regulatory_motif_count  is_transposon amg_flags
# 2                              0          False       MKF
# 11                             0          False        MK
# 12                             0          False        MK
# 15                             0          False       MKB
# 16                             0          False       MKB
# 17                             0          False       MKB
# 26                             0          False        MK
# 39                             0          False       MKE
# 40                             0          False       MKE
# 55                             0          False        MK
# 75                             0          False        MK
# 83                             0          False        VM
# 89                             0          False        MK
# 133                            0          False      MKEF

# %% [markdown]
# ### vSAG2

# %%
# How many genes does DRAM-v recognize?
vsag2_annot = vsag2[vsag2['rank'] != 'E'] # E = no annotation
len(vsag2_annot)
# Out:
# 60

# %%
# subset out AMGs
vsag2_amg = vsag2_annot[vsag2_annot['amg_flags'].str.contains('M')]
len(vsag2_amg)
# Out:
# 4

# %%
vsag2_amg['kegg_hit'].value_counts()
# Out:
# cobaltochelatase CobS [EC:6.6.1.2]             1
# NA                                             1
# nitrite reductase (NO-forming) [EC:1.7.2.1]    1
# small subunit ribosomal protein S21            1
# Name: kegg_hit, dtype: int64

# %%
vsag2_amg['viral_hit'].value_counts()
# Out:
# NA                                                                    2
# YP_009325124.1 porphyrin biosynthesis [Synechococcus phage S-WAM1]    1
# YP_009810895.1 cytidyltransferase [Synechococcus phage S-T4]          1
# Name: viral_hit, dtype: int64

# %%
vsag2_amg['pfam_hits'].value_counts()
# Out:
# AAA domain (dynein-related subfamily) [PF07728.17]; ATPase family associated with various cellular activities (AAA) [PF07726.14]; P-loop containing dynein motor region [PF12775.10]; ATPase family associated with various cellular activities (AAA) [PF00004.32]    1
# Cytidylyltransferase-like [PF01467.29]                                                                                                                                                                                                                                1
# Multicopper oxidase [PF07732.18]                                                                                                                                                                                                                                      1
# Ribosomal protein S21 [PF01165.23]                                                                                                                                                                                                                                    1
# Name: pfam_hits, dtype: int64

# %%
vsag2_amg
# Out:
#                            Unnamed: 0           fasta  \
# 83    SCGC_AM-654-E17_contig3||full_8  cv1_AM-654-E17
# 141  SCGC_AM-654-E17_contig4||full_23  cv1_AM-654-E17
# 159  SCGC_AM-654-E17_contig83||full_1  cv1_AM-654-E17
# 182  SCGC_AM-654-E17_contig8||full_20  cv1_AM-654-E17
#
#                            scaffold  gene_position  start_position  \
# 83    SCGC_AM-654-E17_contig3||full              8            3428
# 141   SCGC_AM-654-E17_contig4||full             23           17813
# 159  SCGC_AM-654-E17_contig83||full              1               1
# 182   SCGC_AM-654-E17_contig8||full             20            8293
#
#      end_position  strandedness rank   ko_id  \
# 83           4621            -1    C  K09882
# 141         18721             1    D      NA
# 159          1038             1    C  K00368
# 182          8559             1    C  K02970
#
#                                         kegg_hit        viral_id  \
# 83            cobaltochelatase CobS [EC:6.6.1.2]  YP_009325124.1
# 141                                           NA  YP_009810895.1
# 159  nitrite reductase (NO-forming) [EC:1.7.2.1]              NA
# 182          small subunit ribosomal protein S21              NA
#
#                                              viral_hit viral_RBH  \
# 83   YP_009325124.1 porphyrin biosynthesis [Synecho...      True
# 141  YP_009810895.1 cytidyltransferase [Synechococc...     False
# 159                                                 NA        NA
# 182                                                 NA        NA
#
#     viral_identity viral_bitScore viral_eVal peptidase_id peptidase_family  \
# 83           0.616          377.0        0.0           NA               NA
# 141          0.472          165.0        0.0           NA               NA
# 159             NA             NA         NA           NA               NA
# 182             NA             NA         NA           NA               NA
#
#     peptidase_hit peptidase_RBH peptidase_identity peptidase_bitScore  \
# 83             NA            NA                 NA                 NA
# 141            NA            NA                 NA                 NA
# 159            NA            NA                 NA                 NA
# 182            NA            NA                 NA                 NA
#
#     peptidase_eVal                                          pfam_hits  \
# 83              NA  AAA domain (dynein-related subfamily) [PF07728...
# 141             NA             Cytidylyltransferase-like [PF01467.29]
# 159             NA                   Multicopper oxidase [PF07732.18]
# 182             NA                 Ribosomal protein S21 [PF01165.23]
#
#     cazy_ids cazy_hits cazy_subfam_ec cazy_best_hit  vogdb_id  \
# 83        NA        NA             NA            NA  VOG02489
# 141       NA        NA             NA            NA        NA
# 159       NA        NA             NA            NA        NA
# 182       NA        NA             NA            NA  VOG04372
#
#                                             vogdb_hits vogdb_categories  \
# 83   sp|P04526|LOADL_BPT4 Sliding-clamp-loader larg...            Xr;Xh
# 141                                                 NA               NA
# 159                                                 NA               NA
# 182  sp|A4THT0|RS21_YERPP 30S ribosomal protein S21...               Xr
#
#      heme_regulatory_motif_count  is_transposon amg_flags
# 83                             0          False       VMF
# 141                            0          False        MK
# 159                            0          False       MKF
# 182                            0          False        VM

# %% [markdown]
# ### vSAG3

# %%
# How many genes does DRAM-v recognize?
vsag3_annot = vsag3[vsag3['rank'] != 'E'] # E = no annotation
len(vsag3_annot)
# Out:
# 19

# %%
# subset out AMGs
vsag3_amg = vsag3_annot[vsag3_annot['amg_flags'].str.contains('M')]
len(vsag3_amg)
# Out:
# 1

# %%
vsag3_amg['kegg_hit'].value_counts()
# Out:
# NA    1
# Name: kegg_hit, dtype: int64

# %%
vsag3_amg['viral_hit'].value_counts()
# Out:
# YP_005087467.1 ribonucleotide reductase [Cyanophage NATL1A-7]    1
# Name: viral_hit, dtype: int64

# %%
vsag3_amg['pfam_hits'].value_counts()
# Out:
# Ribonucleotide reductase, barrel domain [PF02867.18]    1
# Name: pfam_hits, dtype: int64

# %%
vsag3_amg
# Out:
#                           Unnamed: 0           fasta  \
# 11  SCGC_AM-656-P04_contig1||full_12  cv1_AM-656-P04
#
#                          scaffold  gene_position  start_position  \
# 11  SCGC_AM-656-P04_contig1||full             12            8234
#
#     end_position  strandedness rank ko_id kegg_hit        viral_id  \
# 11          9616             1    D    NA       NA  YP_005087467.1
#
#                                             viral_hit viral_RBH  \
# 11  YP_005087467.1 ribonucleotide reductase [Cyano...      True
#
#    viral_identity viral_bitScore viral_eVal peptidase_id peptidase_family  \
# 11          0.756          698.0        0.0           NA               NA
#
#    peptidase_hit peptidase_RBH peptidase_bitScore peptidase_eVal  \
# 11            NA            NA                 NA             NA
#
#    peptidase_identity                                          pfam_hits  \
# 11                 NA  Ribonucleotide reductase, barrel domain [PF028...
#
#     vogdb_id                                         vogdb_hits  \
# 11  VOG00122  sp|P00452|RIR1_ECOLI Ribonucleoside-diphosphat...
#
#    vogdb_categories  heme_regulatory_motif_count  is_transposon amg_flags
# 11               Xh                            0          False       MKE

# %% [markdown]
# ### vSAG4

# %%
# How many genes does DRAM-v recognize?
vsag4_annot = vsag4[vsag4['rank'] != 'E'] # E = no annotation
len(vsag4_annot)
# Out:
# 10

# %%
# subset out AMGs
vsag4_amg = vsag4_annot[vsag4_annot['amg_flags'].str.contains('M')]
len(vsag4_amg)
# Out:
# 1

# %%
vsag4_amg['kegg_hit'].value_counts()
# Out:
# NA    1
# Name: kegg_hit, dtype: int64

# %%
vsag4_amg['viral_hit'].value_counts()
# Out:
# YP_009831807.1 ribonucleotide-diphosphate reductase [Streptomyces phage BRock]    1
# Name: viral_hit, dtype: int64

# %%
vsag4_amg['pfam_hits'].value_counts()
# Out:
# Ribonucleotide reductase, barrel domain [PF02867.18]    1
# Name: pfam_hits, dtype: int64

# %%
vsag4_amg
# Out:
#                           Unnamed: 0           fasta  \
# 16  SCGC_AM-662-D22_contig3||full_17  cv1_AM-662-D22
#
#                          scaffold  gene_position  start_position  \
# 16  SCGC_AM-662-D22_contig3||full             17            6294
#
#     end_position  strandedness rank ko_id kegg_hit        viral_id  \
# 16          7940             1    D    NA       NA  YP_009831807.1
#
#                                             viral_hit viral_RBH  \
# 16  YP_009831807.1 ribonucleotide-diphosphate redu...      True
#
#    viral_identity viral_bitScore viral_eVal  \
# 16          0.464          454.0        0.0
#
#                                             pfam_hits  vogdb_id  \
# 16  Ribonucleotide reductase, barrel domain [PF028...  VOG00122
#
#                                            vogdb_hits vogdb_categories  \
# 16  sp|P00452|RIR1_ECOLI Ribonucleoside-diphosphat...               Xh
#
#     heme_regulatory_motif_count  is_transposon amg_flags
# 16                            0          False       MKE

# %% [markdown]
# ### vSAG5

# %%
# How many genes does DRAM-v recognize?
vsag5_annot = vsag5[vsag5['rank'] != 'E'] # E = no annotation
len(vsag5_annot)
# Out:
# 52

# %%
# subset out AMGs
vsag5_amg = vsag5_annot[vsag5_annot['amg_flags'].str.contains('M')]
len(vsag5_amg)
# Out:
# 11

# %%
vsag5_amg['kegg_hit'].value_counts()
# Out:
# NA                                                                                      5
# small subunit ribosomal protein S21                                                     1
# ribonucleoside-diphosphate reductase beta chain [EC:1.17.4.1]                           1
# ribonucleoside-diphosphate reductase alpha chain [EC:1.17.4.1]                          1
# GTP cyclohydrolase IA [EC:3.5.4.16]                                                     1
# 6-pyruvoyltetrahydropterin/6-carboxytetrahydropterin synthase [EC:4.2.3.12 4.1.2.50]    1
# large subunit ribosomal protein L31                                                     1
# Name: kegg_hit, dtype: int64

# %%
vsag5_amg['viral_hit'].value_counts()
# Out:
# NA                                                                                                              4
# YP_010761232.1 S-adenosylmethionine decarboxylase proenzyme (TIGR03330) [uncultured phage_MedDCM-OCT-S35-C6]    1
# YP_214387.1 2OG-Fe(II) oxygenase [Prochlorococcus phage P-SSM2]                                                 1
# YP_009810888.1 ribonucleoside diphosphate reductase small subunit [Synechococcus phage S-T4]                    1
# YP_009140943.1 ribonucleotide reductase large subunit [Synechococcus phage ACG-2014i]                           1
# YP_010114473.1 GTP cyclohydrolase [Flavobacterium phage vB_FspM_immuto_2-6A]                                    1
# YP_010678988.1 QueD-like 6-pyruvoyl-tetrahydropterin synthase [Pseudomonas phage vB_PaeM_PA5oct]                1
# YP_007677334.1 cytidyltransferase [Synechococcus phage S-SSM4]                                                  1
# Name: viral_hit, dtype: int64

# %%
vsag5_amg['pfam_hits'].value_counts()
# Out:
# S-adenosylmethionine decarboxylase [PF02675.18]                                                                                                1
# Putative 2OG-Fe(II) oxygenase [PF13759.9]                                                                                                      1
# Cadherin domain [PF00028.20]                                                                                                                   1
# Sulfotransferase family [PF03567.17]                                                                                                           1
# NA                                                                                                                                             1
# Ribonucleotide reductase, small chain [PF00268.24]                                                                                             1
# Ribonucleotide reductase, barrel domain [PF02867.18]; Ribonucleotide reductase, all-alpha domain [PF00317.24]; ATP cone domain [PF03477.19]    1
# GTP cyclohydrolase I [PF01227.25]                                                                                                              1
# 6-pyruvoyl tetrahydropterin synthase [PF01242.22]                                                                                              1
# Ribosomal protein L31 [PF01197.21]                                                                                                             1
# 5' nucleotidase, deoxy (Pyrimidine), cytosolic type C protein (NT5C) [PF06941.15]; Cytidylyltransferase-like [PF01467.29]                      1
# Name: pfam_hits, dtype: int64

# %%
vsag5_amg
# Out:
#                             Unnamed: 0           fasta  \
# 4     SCGC_AM-666-P13_contig12||full_5  cv1_AM-666-P13
# 56   SCGC_AM-666-P13_contig12||full_57  cv1_AM-666-P13
# 64    SCGC_AM-666-P13_contig14||full_1  cv1_AM-666-P13
# 66    SCGC_AM-666-P13_contig14||full_3  cv1_AM-666-P13
# 78   SCGC_AM-666-P13_contig14||full_15  cv1_AM-666-P13
# 90   SCGC_AM-666-P13_contig14||full_27  cv1_AM-666-P13
# 91   SCGC_AM-666-P13_contig14||full_28  cv1_AM-666-P13
# 114  SCGC_AM-666-P13_contig30||full_14  cv1_AM-666-P13
# 121  SCGC_AM-666-P13_contig30||full_21  cv1_AM-666-P13
# 147  SCGC_AM-666-P13_contig60||full_11  cv1_AM-666-P13
# 161   SCGC_AM-666-P13_contig65||full_3  cv1_AM-666-P13
#
#                            scaffold  gene_position  start_position  \
# 4    SCGC_AM-666-P13_contig12||full              5            3502
# 56   SCGC_AM-666-P13_contig12||full             57           33659
# 64   SCGC_AM-666-P13_contig14||full              1               1
# 66   SCGC_AM-666-P13_contig14||full              3            4833
# 78   SCGC_AM-666-P13_contig14||full             15           12620
# 90   SCGC_AM-666-P13_contig14||full             27           20205
# 91   SCGC_AM-666-P13_contig14||full             28           21340
# 114  SCGC_AM-666-P13_contig30||full             14            5650
# 121  SCGC_AM-666-P13_contig30||full             21            8895
# 147  SCGC_AM-666-P13_contig60||full             11            4859
# 161  SCGC_AM-666-P13_contig65||full              3             442
#
#      end_position  strandedness rank   ko_id  \
# 4            3885            -1    D      NA
# 56          34366             1    D      NA
# 64           3672             1    D      NA
# 66           5429             1    D      NA
# 78          12877            -1    C  K02970
# 90          21302            -1    C  K00526
# 91          23682            -1    C  K00525
# 114          6327            -1    C  K01495
# 121          9374            -1    C  K01737
# 147          5083            -1    C  K02909
# 161          1566            -1    D      NA
#
#                                               kegg_hit        viral_id  \
# 4                                                   NA  YP_010761232.1
# 56                                                  NA     YP_214387.1
# 64                                                  NA              NA
# 66                                                  NA              NA
# 78                 small subunit ribosomal protein S21              NA
# 90   ribonucleoside-diphosphate reductase beta chai...  YP_009810888.1
# 91   ribonucleoside-diphosphate reductase alpha cha...  YP_009140943.1
# 114                GTP cyclohydrolase IA [EC:3.5.4.16]  YP_010114473.1
# 121  6-pyruvoyltetrahydropterin/6-carboxytetrahydro...  YP_010678988.1
# 147                large subunit ribosomal protein L31              NA
# 161                                                 NA  YP_007677334.1
#
#                                              viral_hit viral_RBH  \
# 4    YP_010761232.1 S-adenosylmethionine decarboxyl...     False
# 56   YP_214387.1 2OG-Fe(II) oxygenase [Prochlorococ...     False
# 64                                                  NA        NA
# 66                                                  NA        NA
# 78                                                  NA        NA
# 90   YP_009810888.1 ribonucleoside diphosphate redu...      True
# 91   YP_009140943.1 ribonucleotide reductase large ...      True
# 114  YP_010114473.1 GTP cyclohydrolase [Flavobacter...     False
# 121  YP_010678988.1 QueD-like 6-pyruvoyl-tetrahydro...     False
# 147                                                 NA        NA
# 161  YP_007677334.1 cytidyltransferase [Synechococc...     False
#
#     viral_identity viral_bitScore viral_eVal peptidase_id peptidase_family  \
# 4            0.505          115.0        0.0           NA               NA
# 56            0.39           66.0        0.0           NA               NA
# 64              NA             NA         NA   MER0257111              U69
# 66              NA             NA         NA           NA               NA
# 78              NA             NA         NA           NA               NA
# 90           0.676          506.0        0.0           NA               NA
# 91           0.728         1127.0        0.0           NA               NA
# 114          0.389          140.0        0.0           NA               NA
# 121          0.446          125.0        0.0           NA               NA
# 147             NA             NA         NA           NA               NA
# 161          0.508          177.0        0.0           NA               NA
#
#                                          peptidase_hit peptidase_RBH  \
# 4                                                   NA            NA
# 56                                                  NA            NA
# 64   MER0257111 - family U69 unassigned peptidases ...         False
# 66                                                  NA            NA
# 78                                                  NA            NA
# 90                                                  NA            NA
# 91                                                  NA            NA
# 114                                                 NA            NA
# 121                                                 NA            NA
# 147                                                 NA            NA
# 161                                                 NA            NA
#
#     peptidase_identity peptidase_bitScore peptidase_eVal  \
# 4                   NA                 NA             NA
# 56                  NA                 NA             NA
# 64               0.257               78.0            0.0
# 66                  NA                 NA             NA
# 78                  NA                 NA             NA
# 90                  NA                 NA             NA
# 91                  NA                 NA             NA
# 114                 NA                 NA             NA
# 121                 NA                 NA             NA
# 147                 NA                 NA             NA
# 161                 NA                 NA             NA
#
#                                              pfam_hits  vogdb_id  \
# 4      S-adenosylmethionine decarboxylase [PF02675.18]  VOG01568
# 56           Putative 2OG-Fe(II) oxygenase [PF13759.9]  VOG00052
# 64                        Cadherin domain [PF00028.20]        NA
# 66                Sulfotransferase family [PF03567.17]        NA
# 78                                                  NA        NA
# 90   Ribonucleotide reductase, small chain [PF00268...  VOG00527
# 91   Ribonucleotide reductase, barrel domain [PF028...  VOG00122
# 114                  GTP cyclohydrolase I [PF01227.25]  VOG02430
# 121  6-pyruvoyl tetrahydropterin synthase [PF01242.22]  VOG02682
# 147                 Ribosomal protein L31 [PF01197.21]        NA
# 161  5' nucleotidase, deoxy (Pyrimidine), cytosolic...  VOG00418
#
#                                             vogdb_hits vogdb_categories  \
# 4    sp|Q7V558|SPEH_PROMM S-adenosylmethionine deca...               Xh
# 56                     REFSEQ 2OG-Fe(II) oxygenase; Xu               Xu
# 64                                                  NA               NA
# 66                                                  NA               NA
# 78                                                  NA               NA
# 90   sp|P69924|RIR2_ECOLI Ribonucleoside-diphosphat...               Xh
# 91   sp|P00452|RIR1_ECOLI Ribonucleoside-diphosphat...               Xh
# 114      sp|A4J5D0|GCH1_DESRM GTP cyclohydrolase 1; Xh               Xh
# 121  sp|Q1RHI6|QUED_RICBR 6-carboxy-5,6,7,8-tetrahy...               Xh
# 147                                                 NA               NA
# 161  sp|P59935|53DR_BPKV4 Putative 5'(3')-deoxyribo...               Xu
#
#      heme_regulatory_motif_count  is_transposon amg_flags
# 4                              0          False       MKF
# 56                             0          False        MK
# 64                             0          False        MF
# 66                             0          False       MKF
# 78                             0          False         M
# 90                             0          False       MKE
# 91                             0          False       MKE
# 114                            0          False        MK
# 121                            0          False        MK
# 147                            0          False        MF
# 161                            0          False       MKF

# %% [markdown]
# ## vMAGs

# %% [markdown]
# ### vMAG1

# %%
# How many genes does DRAM-v recognize?
vmag1_annot = vmag1[vmag1['rank'] != 'E'] # E = no annotation
len(vmag1_annot)
# Out:
# 20

# %%
# subset out AMGs
vmag1_amg = vmag1_annot[vmag1_annot['amg_flags'].str.contains('M')]
len(vmag1_amg)
# Out:
# 0

# %% [markdown]
# ### vMAG2

# %%
# How many genes does DRAM-v recognize?
vmag2_annot = vmag2[vmag2['rank'] != 'E'] # E = no annotation
len(vmag2_annot)
# Out:
# 9

# %%
# subset out AMGs
vmag2_amg = vmag2_annot[vmag2_annot['amg_flags'].str.contains('M')]
len(vmag2_amg)
# Out:
# 2

# %%
vmag2_amg['kegg_hit'].value_counts()
# Out:
# GTP cyclohydrolase IA [EC:3.5.4.16]    1
# NA                                     1
# Name: kegg_hit, dtype: int64

# %%
vmag2_amg['viral_hit'].value_counts()
# Out:
# YP_008125321.1 GTP cyclohydrolase [Vibrio phage nt-1]    1
# NA                                                       1
# Name: viral_hit, dtype: int64

# %%
vmag2_amg['pfam_hits'].value_counts()
# Out:
# GTP cyclohydrolase I [PF01227.25]                   1
# Queuosine biosynthesis protein QueC [PF06508.16]    1
# Name: pfam_hits, dtype: int64

# %%
vmag2_amg
# Out:
#                 Unnamed: 0           fasta             scaffold  \
# 12  jv-119-k141_5050887_13  jv-119-vMAG_32  jv-119-k141_5050887
# 18   jv-119-k141_6904186_6  jv-119-vMAG_32  jv-119-k141_6904186
#
#     gene_position  start_position  end_position  strandedness rank   ko_id  \
# 12             13            9434         10111             1    C  K01495
# 18              6            3791          4435             1    D      NA
#
#                                kegg_hit        viral_id  \
# 12  GTP cyclohydrolase IA [EC:3.5.4.16]  YP_008125321.1
# 18                                   NA              NA
#
#                                             viral_hit viral_RBH  \
# 12  YP_008125321.1 GTP cyclohydrolase [Vibrio phag...     False
# 18                                                 NA        NA
#
#    viral_identity viral_bitScore viral_eVal peptidase_id peptidase_family  \
# 12          0.437          143.0        0.0           NA               NA
# 18             NA             NA         NA           NA               NA
#
#    peptidase_hit peptidase_RBH peptidase_bitScore peptidase_eVal  \
# 12            NA            NA                 NA             NA
# 18            NA            NA                 NA             NA
#
#    peptidase_identity                                         pfam_hits  \
# 12                 NA                 GTP cyclohydrolase I [PF01227.25]
# 18                 NA  Queuosine biosynthesis protein QueC [PF06508.16]
#
#     vogdb_id                                     vogdb_hits vogdb_categories  \
# 12  VOG02430  sp|A4J5D0|GCH1_DESRM GTP cyclohydrolase 1; Xh               Xh
# 18        NA                                             NA               NA
#
#     heme_regulatory_motif_count  is_transposon amg_flags
# 12                            0          False       MKF
# 18                            0          False       MKF

# %% [markdown]
# ### vMAG3

# %%
# How many genes does DRAM-v recognize?
vmag3_annot = vmag3[vmag3['rank'] != 'E'] # E = no annotation
len(vmag3_annot)
# Out:
# 3

# %%
# subset out AMGs
vmag3_amg = vmag3_annot[vmag3_annot['amg_flags'].str.contains('M')]
len(vmag3_amg)
# Out:
# 0

# %% [markdown]
# ### vMAG4

# %%
# How many genes does DRAM-v recognize?
vmag4_annot = vmag4[vmag4['rank'] != 'E'] # E = no annotation
len(vmag4_annot)
# Out:
# 8

# %%
# subset out AMGs
vmag4_amg = vmag4_annot[vmag4_annot['amg_flags'].str.contains('M')]
len(vmag4_amg)
# Out:
# 0

# %% [markdown]
# ### vMAG5

# %%
# How many genes does DRAM-v recognize?
vmag5_annot = vmag5[vmag5['rank'] != 'E'] # E = no annotation
len(vmag5_annot)
# Out:
# 19

# %%
# subset out AMGs
vmag5_amg = vmag5_annot[vmag5_annot['amg_flags'].str.contains('M')]
len(vmag5_amg)
# Out:
# 2

# %%
vmag5_amg['kegg_hit'].value_counts()
# Out:
# NA    2
# Name: kegg_hit, dtype: int64

# %%
vmag5_amg['viral_hit'].value_counts()
# Out:
# YP_009210858.1 carboxylate deaminase [Mycobacterium phage Vincenzo]    1
# NA                                                                     1
# Name: viral_hit, dtype: int64

# %%
vmag5_amg['pfam_hits'].value_counts()
# Out:
# Pyridoxal-phosphate dependent enzyme [PF00291.28]    1
# Sulfotransferase family [PF03567.17]                 1
# Name: pfam_hits, dtype: int64

# %%
vmag5_amg
# Out:
#                 Unnamed: 0           fasta             scaffold  \
# 28  jv-154-k141_1078564_29  jv-154-vMAG_44  jv-154-k141_1078564
# 86   jv-154-k141_2919407_3  jv-154-vMAG_44  jv-154-k141_2919407
#
#     gene_position  start_position  end_position  strandedness rank ko_id  \
# 28             29           17463         18254             1    D    NA
# 86              3            2214          2882            -1    D    NA
#
#    kegg_hit        viral_id  \
# 28       NA  YP_009210858.1
# 86       NA              NA
#
#                                             viral_hit viral_RBH  \
# 28  YP_009210858.1 carboxylate deaminase [Mycobact...     False
# 86                                                 NA        NA
#
#    viral_identity viral_bitScore viral_eVal  \
# 28          0.217           73.0        0.0
# 86             NA             NA         NA
#
#                                             pfam_hits vogdb_id vogdb_hits  \
# 28  Pyridoxal-phosphate dependent enzyme [PF00291.28]       NA         NA
# 86               Sulfotransferase family [PF03567.17]       NA         NA
#
#    vogdb_categories  heme_regulatory_motif_count  is_transposon amg_flags
# 28               NA                            0          False        MK
# 86               NA                            0          False       MKF
